# %% [markdown]
# <a href="https://colab.research.google.com/github/limyerin/contest/blob/main/data_tidy(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **귀농귀촌 데이터 정리**

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (6,838 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
data= pd.read_excel("/content/drive/MyDrive/data/data1.xlsx",engine='openpyxl')
data
# Out:
#                                ind     y19     y20     y21  Unnamed: 4  \
# 0         귀농귀촌 온라인 교육 이수여부_사례수 (명)  2081.0  2038.0  3000.0         NaN
# 1          귀농귀촌 온라인 교육 이수여부_이수 (%)    21.5    20.5    24.2         NaN
# 2     귀농귀촌 온라인 교육 이수여부_이수하지 않음 (%)    78.5    79.5    75.8         NaN
# 3        귀농귀촌 오프라인 교육 이수여부_사례수 (명)  2081.0  2038.0  3000.0         NaN
# 4         귀농귀촌 오프라인 교육 이수여부_이수 (%)    56.6    43.8    42.5         NaN
# 5    귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (%)    43.4    56.2    57.5         NaN
# 6            귀농귀촌 인턴십 이수여부_사례수 (명)  2081.0  2038.0  3000.0         NaN
# 7             귀농귀촌 인턴십 이수여부_이수 (%)    14.9    11.2    16.8         NaN
# 8        귀농귀촌 인턴십 이수여부_이수하지 않음 (%)    85.1    88.8    83.2         NaN
# 9                              NaN     NaN     NaN     NaN         NaN
# 10               귀농귀촌교육개선점_사례수 (명)  2086.0  2028.0  3000.0         NaN
# 11     귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (%)    43.2    43.8    40.5         NaN
# ...

# %%
data1=data.set_index("ind")
data1.columns
# Out:
# Index(['y19', 'y20', 'y21', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'], dtype='object')

# %%
data1.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'],axis=1,inplace=True)

# %%
data1
# Out:
#                                    y19     y20     y21
# ind
# 귀농귀촌 온라인 교육 이수여부_사례수 (명)        2081.0  2038.0  3000.0
# 귀농귀촌 온라인 교육 이수여부_이수 (%)           21.5    20.5    24.2
# 귀농귀촌 온라인 교육 이수여부_이수하지 않음 (%)      78.5    79.5    75.8
# 귀농귀촌 오프라인 교육 이수여부_사례수 (명)       2081.0  2038.0  3000.0
# 귀농귀촌 오프라인 교육 이수여부_이수 (%)          56.6    43.8    42.5
# 귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (%)     43.4    56.2    57.5
# 귀농귀촌 인턴십 이수여부_사례수 (명)           2081.0  2038.0  3000.0
# 귀농귀촌 인턴십 이수여부_이수 (%)              14.9    11.2    16.8
# 귀농귀촌 인턴십 이수여부_이수하지 않음 (%)         85.1    88.8    83.2
# NaN                                NaN     NaN     NaN
# 귀농귀촌교육개선점_사례수 (명)               2086.0  2028.0  3000.0
# 귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (%)       43.2    43.8    40.5
# 귀농귀촌교육개선점_수준별 강좌 개설 (%)           15.4    16.6    20.1
# 귀농귀촌교육개선점_강사의 전문성 증대 (%)           4.5     7.4     8.3
# 귀농귀촌교육개선점_교육 비용 지원 (%)             6.2     3.8     4.9
# 귀농귀촌교육개선점_현장 실습 연계 강화 (%)         11.3    10.7     8.4
# ...

# %% [markdown]
# - 파일마다 교육 이수자수가 다름
# - 퍼센트로 결과가 나와있음
# - 실제 명수로 계산

# %% [markdown]
# 엑셀로 계산해 얻은 사람 데이터 정리

# %%
pdata= pd.read_excel("/content/drive/MyDrive/data/data_person.xlsx",engine='openpyxl')
pdata
# Out:
#                                ind     y19     y20     y21  Unnamed: 4  \
# 0         귀농귀촌 온라인 교육 이수여부_사례수 (명)  2081.0  2038.0  3000.0         NaN
# 1          귀농귀촌 온라인 교육 이수여부_이수 (%)    21.5    20.5    24.2         NaN
# 2     귀농귀촌 온라인 교육 이수여부_이수하지 않음 (%)    78.5    79.5    75.8         NaN
# 3        귀농귀촌 오프라인 교육 이수여부_사례수 (명)  2081.0  2038.0  3000.0         NaN
# 4         귀농귀촌 오프라인 교육 이수여부_이수 (%)    56.6    43.8    42.5         NaN
# 5    귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (%)    43.4    56.2    57.5         NaN
# 6            귀농귀촌 인턴십 이수여부_사례수 (명)  2081.0  2038.0  3000.0         NaN
# 7             귀농귀촌 인턴십 이수여부_이수 (%)    14.9    11.2    16.8         NaN
# 8        귀농귀촌 인턴십 이수여부_이수하지 않음 (%)    85.1    88.8    83.2         NaN
# 9                귀농귀촌교육개선점_사례수 (명)  2086.0  2028.0  3000.0         NaN
# 10     귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (%)    43.2    43.8    40.5         NaN
# 11         귀농귀촌교육개선점_수준별 강좌 개설 (%)    15.4    16.6    20.1         NaN
# ...

# %%
# pdata의 컬럼 불러오기
pdata.columns
# Out:
# Index(['ind', 'y19', 'y20', 'y21', 'Unnamed: 4', 'Ind', 'Y19', 'Y20', 'Y21'], dtype='object')

# %%
# 'ind', 'y19', 'y20', 'y21', 'Unnamed: 4' 컬럼 제거
pdata2 = pdata.drop(['ind', 'y19', 'y20', 'y21', 'Unnamed: 4'],axis=1,inplace=True)
pdata2

# %%
# #VALUE!-> - 바꾸기

#df = pdata.replace('#VALUE!','-')  # .... datatype이 object로 나오니 그냥 0으로 변경할 것
#df
# Out:
#                                Ind       Y19       Y20      Y21
# 0         귀농귀촌 온라인 교육 이수여부_사례수 (명)  2081.000    2038.0   3000.0
# 1          귀농귀촌 온라인 교육 이수여부_이수 (명)   447.415    417.79      726
# 2     귀농귀촌 온라인 교육 이수여부_이수하지 않음 (명)  1633.585   1620.21     2274
# 3        귀농귀촌 오프라인 교육 이수여부_사례수 (명)  2081.000    2038.0   3000.0
# 4         귀농귀촌 오프라인 교육 이수여부_이수 (명)  1177.846   892.644     1275
# 5    귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (명)   903.154  1145.356     1725
# 6            귀농귀촌 인턴십 이수여부_사례수 (명)  2081.000    2038.0   3000.0
# 7             귀농귀촌 인턴십 이수여부_이수 (명)   310.069   228.256      504
# 8        귀농귀촌 인턴십 이수여부_이수하지 않음 (명)  1770.931  1809.744     2496
# 9                귀농귀촌교육개선점_사례수 (명)  2086.000    2028.0   3000.0
# 10     귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (명)   888.264   888.264     1215
# 11         귀농귀촌교육개선점_수준별 강좌 개설 (명)   321.244   336.648      603
# 12        귀농귀촌교육개선점_강사의 전문성 증대 (명)    93.870   150.072      249
# 13          귀농귀촌교육개선점_교육 비용 지원 (명)   129.332    77.064      147
# ...

# %%
pdata.set_index('Ind')
# Out:
#                                      Y19       Y20      Y21
# Ind
# 귀농귀촌 온라인 교육 이수여부_사례수 (명)        2081.000    2038.0   3000.0
# 귀농귀촌 온라인 교육 이수여부_이수 (명)          447.415    417.79      726
# 귀농귀촌 온라인 교육 이수여부_이수하지 않음 (명)    1633.585   1620.21     2274
# 귀농귀촌 오프라인 교육 이수여부_사례수 (명)       2081.000    2038.0   3000.0
# 귀농귀촌 오프라인 교육 이수여부_이수 (명)        1177.846   892.644     1275
# 귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (명)    903.154  1145.356     1725
# 귀농귀촌 인턴십 이수여부_사례수 (명)           2081.000    2038.0   3000.0
# 귀농귀촌 인턴십 이수여부_이수 (명)             310.069   228.256      504
# 귀농귀촌 인턴십 이수여부_이수하지 않음 (명)       1770.931  1809.744     2496
# 귀농귀촌교육개선점_사례수 (명)               2086.000    2028.0   3000.0
# 귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (명)      888.264   888.264     1215
# 귀농귀촌교육개선점_수준별 강좌 개설 (명)          321.244   336.648      603
# 귀농귀촌교육개선점_강사의 전문성 증대 (명)          93.870   150.072      249
# 귀농귀촌교육개선점_교육 비용 지원 (명)           129.332    77.064      147
# 귀농귀촌교육개선점_현장 실습 연계 강화 (명)        235.718   216.996      252
# ...

# %%
df0 = pdata.replace('#VALUE!','0')
df0
# Out:
#                                Ind       Y19       Y20      Y21
# 0         귀농귀촌 온라인 교육 이수여부_사례수 (명)  2081.000    2038.0   3000.0
# 1          귀농귀촌 온라인 교육 이수여부_이수 (명)   447.415    417.79      726
# 2     귀농귀촌 온라인 교육 이수여부_이수하지 않음 (명)  1633.585   1620.21     2274
# 3        귀농귀촌 오프라인 교육 이수여부_사례수 (명)  2081.000    2038.0   3000.0
# 4         귀농귀촌 오프라인 교육 이수여부_이수 (명)  1177.846   892.644     1275
# 5    귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (명)   903.154  1145.356     1725
# 6            귀농귀촌 인턴십 이수여부_사례수 (명)  2081.000    2038.0   3000.0
# 7             귀농귀촌 인턴십 이수여부_이수 (명)   310.069   228.256      504
# 8        귀농귀촌 인턴십 이수여부_이수하지 않음 (명)  1770.931  1809.744     2496
# 9                귀농귀촌교육개선점_사례수 (명)  2086.000    2028.0   3000.0
# 10     귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (명)   888.264   888.264     1215
# 11         귀농귀촌교육개선점_수준별 강좌 개설 (명)   321.244   336.648      603
# 12        귀농귀촌교육개선점_강사의 전문성 증대 (명)    93.870   150.072      249
# 13          귀농귀촌교육개선점_교육 비용 지원 (명)   129.332    77.064      147
# ...

# %%
df1 = df0.round(0).astype({'Y19':int,
                            'Y20':int,
                            'Y21':int})
df1
# Out:
#                                Ind   Y19   Y20   Y21
# 0         귀농귀촌 온라인 교육 이수여부_사례수 (명)  2081  2038  3000
# 1          귀농귀촌 온라인 교육 이수여부_이수 (명)   447   417   726
# 2     귀농귀촌 온라인 교육 이수여부_이수하지 않음 (명)  1634  1620  2274
# 3        귀농귀촌 오프라인 교육 이수여부_사례수 (명)  2081  2038  3000
# 4         귀농귀촌 오프라인 교육 이수여부_이수 (명)  1178   892  1275
# 5    귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (명)   903  1145  1725
# 6            귀농귀촌 인턴십 이수여부_사례수 (명)  2081  2038  3000
# 7             귀농귀촌 인턴십 이수여부_이수 (명)   310   228   504
# 8        귀농귀촌 인턴십 이수여부_이수하지 않음 (명)  1771  1809  2496
# 9                귀농귀촌교육개선점_사례수 (명)  2086  2028  3000
# 10     귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (명)   888   888  1215
# 11         귀농귀촌교육개선점_수준별 강좌 개설 (명)   321   336   603
# 12        귀농귀촌교육개선점_강사의 전문성 증대 (명)    94   150   249
# 13          귀농귀촌교육개선점_교육 비용 지원 (명)   129    77   147
# 14       귀농귀촌교육개선점_현장 실습 연계 강화 (명)   236   216   252
# 15        귀농귀촌교육개선점_교육 시간대 다양화 (명)   136   101   159
# 16        귀농귀촌교육개선점_지리적 접근성 확대 (명)   136   137   201
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ind     47 non-null     object
#  1   Y19     47 non-null     int64
#  2   Y20     47 non-null     int64
#  3   Y21     47 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.6+ KB

# %%
# 귀농귀촌 온라인/오프라인/인턴십 이수여부

df1.iloc[0:9]
# Out:
#                              Ind   Y19   Y20   Y21
# 0       귀농귀촌 온라인 교육 이수여부_사례수 (명)  2081  2038  3000
# 1        귀농귀촌 온라인 교육 이수여부_이수 (명)   447   417   726
# 2   귀농귀촌 온라인 교육 이수여부_이수하지 않음 (명)  1634  1620  2274
# 3      귀농귀촌 오프라인 교육 이수여부_사례수 (명)  2081  2038  3000
# 4       귀농귀촌 오프라인 교육 이수여부_이수 (명)  1178   892  1275
# 5  귀농귀촌 오프라인 교육 이수여부_이수하지 않음 (명)   903  1145  1725
# 6          귀농귀촌 인턴십 이수여부_사례수 (명)  2081  2038  3000
# 7           귀농귀촌 인턴십 이수여부_이수 (명)   310   228   504
# 8      귀농귀촌 인턴십 이수여부_이수하지 않음 (명)  1771  1809  2496

# %%
# 귀농귀촌교육 개선되어야 할 부분

rfrh_improve = df1.iloc[9:21].set_index('Ind')
rfrh_improve
# Out:
#                               Y19   Y20   Y21
# Ind
# 귀농귀촌교육개선점_사례수 (명)            2086  2028  3000
# 귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (명)   888   888  1215
# 귀농귀촌교육개선점_수준별 강좌 개설 (명)       321   336   603
# 귀농귀촌교육개선점_강사의 전문성 증대 (명)       94   150   249
# 귀농귀촌교육개선점_교육 비용 지원 (명)        129    77   147
# 귀농귀촌교육개선점_현장 실습 연계 강화 (명)     236   216   252
# 귀농귀촌교육개선점_교육 시간대 다양화 (명)      136   101   159
# 귀농귀촌교육개선점_지리적 접근성 확대 (명)      136   137   201
# 귀농귀촌교육개선점_온라인 교육 확대 (명)       102    97   177
# 귀농귀촌교육개선점_기타 (명)                6     0     0
# 귀농귀촌교육개선점_없음 (명)               19    16     0
# 귀농귀촌교육개선점_모름/무응답 (명)            8     6     0

# %% [markdown]
# # rfrh_improve 시각화(그래프)
# # 행/열 전환 -> 변수명 영어로 -> % -> 파이그래프

# %%
pi_improve = data1.iloc[10:22].replace('-', 0.0)
pi_improve
# Out:
#                                 y19     y20     y21
# ind
# 귀농귀촌교육개선점_사례수 (명)            2086.0  2028.0  3000.0
# 귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (%)    43.2    43.8    40.5
# 귀농귀촌교육개선점_수준별 강좌 개설 (%)        15.4    16.6    20.1
# 귀농귀촌교육개선점_강사의 전문성 증대 (%)        4.5     7.4     8.3
# 귀농귀촌교육개선점_교육 비용 지원 (%)          6.2     3.8     4.9
# 귀농귀촌교육개선점_현장 실습 연계 강화 (%)      11.3    10.7     8.4
# 귀농귀촌교육개선점_교육 시간대 다양화 (%)        6.5     5.0     5.3
# 귀농귀촌교육개선점_지리적 접근성 확대 (%)        6.5     6.8     6.7
# 귀농귀촌교육개선점_온라인 교육 확대 (%)         4.9     4.8     5.9
# 귀농귀촌교육개선점_기타 (%)                0.3     0.0     0.0
# 귀농귀촌교육개선점_없음 (%)                0.9     0.8     0.0
# 귀농귀촌교육개선점_모름/무응답 (%)            0.4     0.3     0.0

# %%
pi_imp = pi_improve.rename(index={'귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (%)': 'contents',
                                  '귀농귀촌교육개선점_수준별 강좌 개설 (%)' : 'level',
                                  '귀농귀촌교육개선점_강사의 전문성 증대 (%)':'professional',
                                  '귀농귀촌교육개선점_교육 비용 지원 (%)':'cost support',
                                  '귀농귀촌교육개선점_현장 실습 연계 강화 (%)':'field training',
                                  '귀농귀촌교육개선점_교육 시간대 다양화 (%)': 'time diversity',
                                  '귀농귀촌교육개선점_지리적 접근성 확대 (%)':'geo_acessibility',
                                  '귀농귀촌교육개선점_온라인 교육 확대 (%)':'oe_expansion',
                                  '귀농귀촌교육개선점_기타 (%)':'etc',
                                  '귀농귀촌교육개선점_없음 (%)':'no',
                                  '귀농귀촌교육개선점_모름/무응답 (%)':'non-response'})
pi_imp
# Out:
#                       y19     y20     y21
# ind
# 귀농귀촌교육개선점_사례수 (명)  2086.0  2028.0  3000.0
# contents             43.2    43.8    40.5
# level                15.4    16.6    20.1
# professional          4.5     7.4     8.3
# cost support          6.2     3.8     4.9
# field training       11.3    10.7     8.4
# time diversity        6.5     5.0     5.3
# geo_acessibility      6.5     6.8     6.7
# oe_expansion          4.9     4.8     5.9
# etc                   0.3     0.0     0.0
# no                    0.9     0.8     0.0
# non-response          0.4     0.3     0.0

# %%
pi_imp_y19 = pi_imp[['y19']].loc['contents':'non-response']
pi_imp_y19
# Out:
#                    y19
# ind
# contents          43.2
# level             15.4
# professional       4.5
# cost support       6.2
# field training    11.3
# time diversity     6.5
# geo_acessibility   6.5
# oe_expansion       4.9
# etc                0.3
# no                 0.9
# non-response       0.4

# %%
pi_imp_y20 = pi_imp[['y20']].loc['contents':'non-response']
pi_imp_y20
# Out:
#                    y20
# ind
# contents          43.8
# level             16.6
# professional       7.4
# cost support       3.8
# field training    10.7
# time diversity     5.0
# geo_acessibility   6.8
# oe_expansion       4.8
# etc                0.0
# no                 0.8
# non-response       0.3

# %%
pi_imp_y21 = pi_imp[['y21']].loc['contents':'non-response']
pi_imp_y21
# Out:
#                    y21
# ind
# contents          40.5
# level             20.1
# professional       8.3
# cost support       4.9
# field training     8.4
# time diversity     5.3
# geo_acessibility   6.7
# oe_expansion       5.9
# etc                0.0
# no                 0.0
# non-response       0.0

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
pi_imp_y19.groupby(['ind']).sum().plot.pie(y='y19', figsize=(10,10), title = '귀농귀촌 개선되어야 할 부분')
pi_imp_y20.groupby(['ind']).sum().plot.pie(y='y20', figsize=(10,10), title = '귀농귀촌 개선되어야 할 부분')
pi_imp_y21.groupby(['ind']).sum().plot.pie(y='y21', figsize=(10,10), title = '귀농귀촌 개선되어야 할 부분')

# %% [markdown]
# #**19, 20, 21년도 개선되어야 하는 부분 한번에 비교**

# %%
rfrh_improve1 = rfrh_improve.rename(index={'귀농귀촌교육개선점_사례수 (명)':'person',
                                            '귀농귀촌교육개선점_다양한 교육 콘텐츠 개발 (명)': 'contents',
                                            '귀농귀촌교육개선점_수준별 강좌 개설 (명)' : 'level',
                                            '귀농귀촌교육개선점_강사의 전문성 증대 (명)':'professional',
                                            '귀농귀촌교육개선점_교육 비용 지원 (명)':'cost support',
                                            '귀농귀촌교육개선점_현장 실습 연계 강화 (명)':'field training',
                                            '귀농귀촌교육개선점_교육 시간대 다양화 (명)': 'time diversity',
                                            '귀농귀촌교육개선점_지리적 접근성 확대 (명)':'geo_acessibility',
                                            '귀농귀촌교육개선점_온라인 교육 확대 (명)':'oe_expansion',
                                            '귀농귀촌교육개선점_기타 (명)':'etc',
                                            '귀농귀촌교육개선점_없음 (명)':'no',
                                            '귀농귀촌교육개선점_모름/무응답 (명)':'non-response'})
rfrh_improve1
# Out:
#                    Y19   Y20   Y21
# Ind
# person            2086  2028  3000
# contents           888   888  1215
# level              321   336   603
# professional        94   150   249
# cost support       129    77   147
# field training     236   216   252
# time diversity     136   101   159
# geo_acessibility   136   137   201
# oe_expansion       102    97   177
# etc                  6     0     0
# no                  19    16     0
# non-response         8     6     0

# %%
df_imp = rfrh_improve1.T
df_imp
# Out:
# Ind  person  contents  level  professional  cost support  field training  \
# Y19    2086       888    321            94           129             236
# Y20    2028       888    336           150            77             216
# Y21    3000      1215    603           249           147             252
#
# Ind  time diversity  geo_acessibility  oe_expansion  etc  no  non-response
# Y19             136               136           102    6  19             8
# Y20             101               137            97    0  16             6
# Y21             159               201           177    0   0             0

# %% [markdown]
# -> person 비율 다름...

# %%
df_imp.columns
# Out:
# Index(['person', 'contents', 'level', 'professional', 'cost support',
#        'field training', 'time diversity', 'geo_acessibility', 'oe_expansion',
#        'etc', 'no', 'non-response'],
#       dtype='object', name='Ind')

# %%
df_imp.columns.names = ['column']

# %%
df_imp.index
# Out:
# Index(['Y19', 'Y20', 'Y21'], dtype='object')

# %%
df_imp.index.names=['year']

# %%
df_imp
# Out:
# column  person  contents  level  professional  cost support  field training  \
# year
# Y19       2086       888    321            94           129             236
# Y20       2028       888    336           150            77             216
# Y21       3000      1215    603           249           147             252
#
# column  time diversity  geo_acessibility  oe_expansion  etc  no  non-response
# year
# Y19                136               136           102    6  19             8
# Y20                101               137            97    0  16             6
# Y21                159               201           177    0   0             0

# %%
# person 열 삭제
df_imp=df_imp.drop(df_imp.columns[0], axis=1)

# %%
df_imp
# Out:
# column  contents  level  professional  cost support  field training  \
# year
# Y19          888    321            94           129             236
# Y20          888    336           150            77             216
# Y21         1215    603           249           147             252
#
# column  time diversity  geo_acessibility  oe_expansion  etc  no  non-response
# year
# Y19                136               136           102    6  19             8
# Y20                101               137            97    0  16             6
# Y21                159               201           177    0   0             0

# %%
df_imp.index.name
# Out:
# 'year'

# %%
df_imp.columns.name
# Out:
# 'column'

# %%
p_imp = pi_imp.loc['contents':'non-response']
p_imp
# Out:
#                    y19   y20   y21
# ind
# contents          43.2  43.8  40.5
# level             15.4  16.6  20.1
# professional       4.5   7.4   8.3
# cost support       6.2   3.8   4.9
# field training    11.3  10.7   8.4
# time diversity     6.5   5.0   5.3
# geo_acessibility   6.5   6.8   6.7
# oe_expansion       4.9   4.8   5.9
# etc                0.3   0.0   0.0
# no                 0.9   0.8   0.0
# non-response       0.4   0.3   0.0

# %%
p_imp.columns.name = 'year'

# %%
p_imp.index
# Out:
# Index(['contents', 'level', 'professional', 'cost support', 'field training',
#        'time diversity', 'geo_acessibility', 'oe_expansion', 'etc', 'no',
#        'non-response'],
#       dtype='object', name='ind')

# %%
p_imp
# Out:
# year               y19   y20   y21
# ind
# contents          43.2  43.8  40.5
# level             15.4  16.6  20.1
# professional       4.5   7.4   8.3
# cost support       6.2   3.8   4.9
# field training    11.3  10.7   8.4
# time diversity     6.5   5.0   5.3
# geo_acessibility   6.5   6.8   6.7
# oe_expansion       4.9   4.8   5.9
# etc                0.3   0.0   0.0
# no                 0.9   0.8   0.0
# non-response       0.4   0.3   0.0

# %%
p_imp.value_counts
# Out:
# <bound method DataFrame.value_counts of year               y19   y20   y21
# ind
# contents          43.2  43.8  40.5
# level             15.4  16.6  20.1
# professional       4.5   7.4   8.3
# cost support       6.2   3.8   4.9
# field training    11.3  10.7   8.4
# time diversity     6.5   5.0   5.3
# geo_acessibility   6.5   6.8   6.7
# oe_expansion       4.9   4.8   5.9
# etc                0.3   0.0   0.0
# no                 0.9   0.8   0.0
# non-response       0.4   0.3   0.0>

# %%
plt.figure(figsize = (15,8))
chart3=sns.countplot(x='year',hue='ind',data=p_imp)
plt.title("개선", fontsize = 25, pad=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-cad1929c37cc> in <module>()
#       1 plt.figure(figsize = (15,8))
# ----> 2 chart3=sns.countplot(x='year',hue='ind',data=p_imp)
#       3 plt.title("개선", fontsize = 25, pad=20)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
#    3603     )
#    3604
#
# ...

# %%
p_imp.plot(kind='bar', figsize=(20, 10), title = '개선되길 바라는 분야')

# %%
df_imp.plot(kind='bar', figsize=(20, 10), title = '연도별 개선되길 바라는 분야')

# %%
# 귀농귀촌교육 강화되어야 할 부분

rfrh_reinforce = df1.iloc[21:32].set_index('Ind')
rfrh_reinforce
# Out:
#                                Y19   Y20   Y21
# Ind
# 귀농귀촌교육강화점_사례수 (명)             2086  2028  3000
# 귀농귀촌교육강화점_주거 및 전원생활 (명)        555   661   867
# 귀농귀촌교육강화점_귀촌창업 (명)             248   156   333
# 귀농귀촌교육강화점_관계형성 (명)             252   294   615
# 귀농귀촌교육강화점_텃밭 가꾸기 (명)           196   180   348
# 귀농귀촌교육강화점_영농교육 (명)             169   166   207
# 귀농귀촌교육강화점_농업농촌의 이해(기초소양) (명)   202   148   204
# 귀농귀촌교육강화점_제도,정책 (명)            436   387   426
# 귀농귀촌교육강화점_기타 (명)                 4     2     0
# 귀농귀촌교육강화점_없음 (명)                17    26     0
# 귀농귀촌교육강화점_모름/무응답 (명)             6     6     0

# %%
rfrh_reinforce.index
# Out:
# Index(['귀농귀촌교육강화점_사례수 (명)', '귀농귀촌교육강화점_주거 및 전원생활 (명)', '귀농귀촌교육강화점_귀촌창업 (명)',
#        '귀농귀촌교육강화점_관계형성 (명)', '귀농귀촌교육강화점_텃밭 가꾸기 (명)', '귀농귀촌교육강화점_영농교육 (명)',
#        '귀농귀촌교육강화점_농업농촌의 이해(기초소양) (명)', '귀농귀촌교육강화점_제도,정책 (명)',
#        '귀농귀촌교육강화점_기타 (명)', '귀농귀촌교육강화점_없음 (명)', '귀농귀촌교육강화점_모름/무응답 (명)'],
#       dtype='object', name='Ind')

# %%
rfrh_reinforce1 = rfrh_reinforce.rename(index={'귀농귀촌교육강화점_사례수 (명)':'person',
                                           '귀농귀촌교육강화점_주거 및 전원생활 (명)'	:'country life',
                                           '귀농귀촌교육강화점_귀촌창업 (명)'	:'foundation',
                                           '귀농귀촌교육강화점_관계형성 (명)'	:'relationship',
                                           '귀농귀촌교육강화점_텃밭 가꾸기 (명)':"gardening",
                                           '귀농귀촌교육강화점_영농교육 (명)'	:'agricultural education',
                                           '귀농귀촌교육강화점_농업농촌의 이해(기초소양) (명)'	:'rf_understanding',
                                           '귀농귀촌교육강화점_제도,정책 (명)'	:'policy',
                                           '귀농귀촌교육강화점_기타 (명)'	:'etc',
                                           '귀농귀촌교육강화점_없음 (명)'	:'no',
                                           '귀농귀촌교육강화점_모름/무응답 (명)':'non-response'})
rfrh_reinforce1
# Out:
#                          Y19   Y20   Y21
# Ind
# person                  2086  2028  3000
# country life             555   661   867
# foundation               248   156   333
# relationship             252   294   615
# gardening                196   180   348
# agricultural education   169   166   207
# rf_understanding         202   148   204
# policy                   436   387   426
# etc                        4     2     0
# no                        17    26     0
# non-response               6     6     0

# %%
rfrh_rein = rfrh_reinforce1.loc['country life':'non-response'].T
rfrh_rein
# Out:
# Ind  country life  foundation  relationship  gardening  \
# Y19           555         248           252        196
# Y20           661         156           294        180
# Y21           867         333           615        348
#
# Ind  agricultural education  rf_understanding  policy  etc  no  non-response
# Y19                     169               202     436    4  17             6
# Y20                     166               148     387    2  26             6
# Y21                     207               204     426    0   0             0

# %%
rfrh_rein.columns.names = ['column']
rfrh_rein.index.names = ['year']

# %%
rfrh_rein
# Out:
# column  country life  foundation  relationship  gardening  \
# year
# Y19              555         248           252        196
# Y20              661         156           294        180
# Y21              867         333           615        348
#
# column  agricultural education  rf_understanding  policy  etc  no  \
# year
# Y19                        169               202     436    4  17
# Y20                        166               148     387    2  26
# Y21                        207               204     426    0   0
#
# column  non-response
# year
# Y19                6
# Y20                6
# Y21                0

# %%
rfrh_rein.plot(kind='bar', figsize=(20, 10), title = '연도별 강화되면 좋은 점')

# %% [markdown]
# -> 연도별 country life, relationship, policy가 가장 많은 비율 차지

# %%
# 귀농귀촌교육 받지않은 이유

rfrh_nedu = df1.iloc[32:41].set_index('Ind')
rfrh_nedu
# Out:
#                                  Y19   Y20   Y21
# Ind
# 교육받지않이유_사례수 (명)                 1645  1704  2759
# 교육받지않이유_교육에 대해 알지 못해서 (명)        846   736   954
# 교육받지않이유_시간이 없어서 (명)              344   449   731
# 교육받지않이유_적합한 과정(작목, 과목)이 없어 (명)   188   149   411
# 교육받지않이유_내용이 도움이 되지 않아서 (명)       225   340   637
# 교육받지않이유_교육비용 때문에 (명)               8     1    22
# 교육받지않이유_기타 (명)                    26    17     0
# 교육받지않이유_없음 (명)                    10     6     0
# 교육받지않이유_모름/무응답 (명)                 0     0     0

# %%
rfrh_nedu1 = rfrh_nedu.rename(index={'교육받지않이유_사례수 (명)':'person',
                                           '교육받지않이유_교육에 대해 알지 못해서 (명)'	:'not knowing',
                                           '교육받지않이유_시간이 없어서 (명)'	:'no time',
                                           '교육받지않이유_적합한 과정(작목, 과목)이 없어 (명)'	:'no suitable course',
                                           '교육받지않이유_내용이 도움이 되지 않아서 (명)':'unhelpful',
                                           '교육받지않이유_교육비용 때문에 (명)'	:'educational expenses',
                                           '교육받지않이유_기타 (명)'	:'etc',
                                           '교육받지않이유_없음 (명)'	:'no',
                                           '교육받지않이유_모름/무응답 (명)'	:'non-response'})
rfrh_nedu1
# Out:
#                        Y19   Y20   Y21
# Ind
# person                1645  1704  2759
# not knowing            846   736   954
# no time                344   449   731
# no suitable course     188   149   411
# unhelpful              225   340   637
# educational expenses     8     1    22
# etc                     26    17     0
# no                      10     6     0
# non-response             0     0     0

# %%
rfrh_nedu2 = rfrh_nedu1.loc['not knowing':'non-response'].T

rfrh_nedu2.columns.names = ['column']
rfrh_nedu2.index.names = ['year']

rfrh_nedu2
# Out:
# column  not knowing  no time  no suitable course  unhelpful  \
# year
# Y19             846      344                 188        225
# Y20             736      449                 149        340
# Y21             954      731                 411        637
#
# column  educational expenses  etc  no  non-response
# year
# Y19                        8   26  10             0
# Y20                        1   17   6             0
# Y21                       22    0   0             0

# %%
rfrh_nedu2.plot(kind='bar', figsize=(20, 10), title = '연도별 교육받지 않은 이유')

# %%
# 귀농귀촌교육 도움된 정도
rfrh_support = df1.iloc[41:].set_index('Ind')
rfrh_support
# Out:
#                        Y19  Y20  Y21
# Ind
# 교육실제도움정도_사례수 (명)       441  324  241
# 교육실제도움정도_전혀 도움 안됨 (명)    3    1    0
# 교육실제도움정도_도움 안됨 (명)      22   10    1
# 교육실제도움정도_보통 (명)        100   75   32
# 교육실제도움정도_도움 됨 (명)      288  227  194
# 교육실제도움정도_매우 도움 됨 (명)    28    8   11

# %%
rfrh_sup = rfrh_support.rename(index={'교육실제도움정도_사례수 (명)':'person',
                                      '교육실제도움정도_전혀 도움 안됨 (명)'	:'very bad',
                                      '교육실제도움정도_도움 안됨 (명)'	:'bad',
                                      '교육실제도움정도_보통 (명)'	:'normal',
                                      '교육실제도움정도_도움 됨 (명)':'good',
                                      '교육실제도움정도_매우 도움 됨 (명)'	:'very good'})
rfrh_sup
# Out:
#            Y19  Y20  Y21
# Ind
# person     441  324  241
# very bad     3    1    0
# bad         22   10    1
# normal     100   75   32
# good       288  227  194
# very good   28    8   11

# %%
'''
rfrh_sup1 = rfrh_sup.loc['very bad':'very good'].T

rfrh_sup1.columns.names = ['column']
rfrh_sup1.index.names = ['year']

rfrh_sup1
'''
# Out:
# column  very bad  bad  normal  good  very good
# year
# Y19            3   22     100   288         28
# Y20            1   10      75   227          8
# Y21            0    1      32   194         11

# %%
'''
rfrh_sup1.plot(kind='bar', figsize=(20, 10), title = '연도별 교육이 도움된 정도')
'''

# %%
rfrh_sup = pd.read_excel("/content/drive/MyDrive/data/교육_인턴십의_농촌생활_도움_정도_20220726135240.xlsx",engine='openpyxl', index_col = 0)
rfrh_sup
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               도움정도별(1)    2019   2020    2021
# 교육종류별(1)
# 온라인교육          사례수 (명)   448.0  418.0   727.0
# NaN       전혀 도움 안됨 (%)     2.5    1.2     0.4
# NaN          도움 안됨 (%)     8.6   11.8     0.9
# NaN             보통 (%)    26.9   22.1    22.7
# NaN          도움이 됨 (%)    57.8   59.6    69.5
# NaN       매우 도움이 됨 (%)     3.9    5.1     6.5
# NaN         모름/무응답 (%)     0.2    0.2       -
# 오프라인교육         사례수 (명)  1178.0  893.0  1275.0
# NaN       전혀 도움 안됨 (%)     0.5    0.4     0.1
# NaN          도움 안됨 (%)     3.4    3.8     1.4
# NaN             보통 (%)    17.0   19.8    13.3
# NaN          도움이 됨 (%)    70.3   64.0    74.1
# NaN       매우 도움이 됨 (%)     8.8   11.9    11.1
# 인턴십            사례수 (명)   311.0  229.0   503.0
# ...

# %%
oe_rfrh_sup= rfrh_sup.iloc[0:7].set_index('도움정도별(1)')
oe_rfrh_sup
# Out:
#                2019   2020   2021
# 도움정도별(1)
# 사례수 (명)       448.0  418.0  727.0
# 전혀 도움 안됨 (%)    2.5    1.2    0.4
# 도움 안됨 (%)       8.6   11.8    0.9
# 보통 (%)         26.9   22.1   22.7
# 도움이 됨 (%)      57.8   59.6   69.5
# 매우 도움이 됨 (%)    3.9    5.1    6.5
# 모름/무응답 (%)      0.2    0.2      -

# %%
oe_rfrh_sup1 = oe_rfrh_sup.rename(index={'사례수 (명)':'person',
                                      '전혀 도움 안됨 (%)'	:'very bad',
                                      '도움 안됨 (%)'	:'bad',
                                      '보통 (%)'	:'normal',
                                      '도움이 됨 (%)':'good',
                                      '매우 도움이 됨 (%)'	:'very good',
                                      '모름/무응답 (%)' : 'non-response'})
oe_rfrh_sup1
# Out:
#                2019   2020   2021
# 도움정도별(1)
# person        448.0  418.0  727.0
# very bad        2.5    1.2    0.4
# bad             8.6   11.8    0.9
# normal         26.9   22.1   22.7
# good           57.8   59.6   69.5
# very good       3.9    5.1    6.5
# non-response    0.2    0.2      -

# %%
oe_rfrh_sup1 = oe_rfrh_sup1.replace('-', 0.0)
oe_rfrh_sup1
# Out:
#                2019   2020   2021
# 도움정도별(1)
# person        448.0  418.0  727.0
# very bad        2.5    1.2    0.4
# bad             8.6   11.8    0.9
# normal         26.9   22.1   22.7
# good           57.8   59.6   69.5
# very good       3.9    5.1    6.5
# non-response    0.2    0.2    0.0

# %%
oe_rfrh_sup2 = oe_rfrh_sup1.loc['very bad':'non-response'].T
oe_rfrh_sup2
# Out:
# 도움정도별(1)  very bad   bad  normal  good  very good  non-response
# 2019           2.5   8.6    26.9  57.8        3.9           0.2
# 2020           1.2  11.8    22.1  59.6        5.1           0.2
# 2021           0.4   0.9    22.7  69.5        6.5           0.0

# %%
oe_rfrh_sup2.columns.names = ['col']
oe_rfrh_sup2.index.names = ['year']

# %%
oe_rfrh_sup2
# Out:
# col   very bad   bad  normal  good  very good  non-response
# year
# 2019       2.5   8.6    26.9  57.8        3.9           0.2
# 2020       1.2  11.8    22.1  59.6        5.1           0.2
# 2021       0.4   0.9    22.7  69.5        6.5           0.0

# %%
oe_rfrh_sup2.plot(kind='bar', figsize=(20, 10), title = '연도별 온라인 교육이 도움된 정도')

# %%
off_rfrh_sup= rfrh_sup.iloc[7:13].set_index('도움정도별(1)')
off_rfrh_sup
# Out:
#                 2019   2020    2021
# 도움정도별(1)
# 사례수 (명)       1178.0  893.0  1275.0
# 전혀 도움 안됨 (%)     0.5    0.4     0.1
# 도움 안됨 (%)        3.4    3.8     1.4
# 보통 (%)          17.0   19.8    13.3
# 도움이 됨 (%)       70.3   64.0    74.1
# 매우 도움이 됨 (%)     8.8   11.9    11.1

# %%
off_rfrh_sup1 = off_rfrh_sup.rename(index={'사례수 (명)':'person',
                                      '전혀 도움 안됨 (%)'	:'very bad',
                                      '도움 안됨 (%)'	:'bad',
                                      '보통 (%)'	:'normal',
                                      '도움이 됨 (%)':'good',
                                      '매우 도움이 됨 (%)'	:'very good'})
off_rfrh_sup1
# Out:
#              2019   2020    2021
# 도움정도별(1)
# person     1178.0  893.0  1275.0
# very bad      0.5    0.4     0.1
# bad           3.4    3.8     1.4
# normal       17.0   19.8    13.3
# good         70.3   64.0    74.1
# very good     8.8   11.9    11.1

# %%
off_rfrh_sup2= off_rfrh_sup1.loc['very bad':'very good'].T
off_rfrh_sup2
# Out:
# 도움정도별(1) very bad  bad normal  good very good
# 2019          0.5  3.4   17.0  70.3       8.8
# 2020          0.4  3.8   19.8  64.0      11.9
# 2021          0.1  1.4   13.3  74.1      11.1

# %%
off_rfrh_sup2.plot(kind='bar', figsize=(20,10), title='연도별 오프라인 교육이 도움된 정도')

# %%
is_rfrh_sup= rfrh_sup.iloc[13:].set_index('도움정도별(1)')
is_rfrh_sup
# Out:
#                2019   2020   2021
# 도움정도별(1)
# 사례수 (명)       311.0  229.0  503.0
# 전혀 도움 안됨 (%)    1.9    0.0    0.2
# 도움 안됨 (%)       2.3    1.7    0.4
# 보통 (%)         12.4   14.3   15.1
# 도움이 됨 (%)      66.0   62.1   64.7
# 매우 도움이 됨 (%)   16.9   21.0   19.7
# 모름/무응답 (%)      0.4    0.8      -

# %%
is_rfrh_sup1 = is_rfrh_sup.rename(index={'사례수 (명)':'person',
                                      '전혀 도움 안됨 (%)'	:'very bad',
                                      '도움 안됨 (%)'	:'bad',
                                      '보통 (%)'	:'normal',
                                      '도움이 됨 (%)':'good',
                                      '매우 도움이 됨 (%)'	:'very good',
                                      '모름/무응답 (%)' : 'non-response'})
is_rfrh_sup1
# Out:
#                2019   2020   2021
# 도움정도별(1)
# person        311.0  229.0  503.0
# very bad        1.9    0.0    0.2
# bad             2.3    1.7    0.4
# normal         12.4   14.3   15.1
# good           66.0   62.1   64.7
# very good      16.9   21.0   19.7
# non-response    0.4    0.8      -

# %%
is_rfrh_sup1=is_rfrh_sup1.replace('-', 0.0)
is_rfrh_sup1
# Out:
#                2019   2020   2021
# 도움정도별(1)
# person        311.0  229.0  503.0
# very bad        1.9    0.0    0.2
# bad             2.3    1.7    0.4
# normal         12.4   14.3   15.1
# good           66.0   62.1   64.7
# very good      16.9   21.0   19.7
# non-response    0.4    0.8    0.0

# %%
is_rfrh_sup2 = is_rfrh_sup1.loc['very bad':'non-response'].T
is_rfrh_sup2
# Out:
# 도움정도별(1)  very bad  bad  normal  good  very good  non-response
# 2019           1.9  2.3    12.4  66.0       16.9           0.4
# 2020           0.0  1.7    14.3  62.1       21.0           0.8
# 2021           0.2  0.4    15.1  64.7       19.7           0.0

# %%
is_rfrh_sup2.plot(kind='bar', figsize=(20,10), title='연도별 인턴십 교육이 도움된 정도')
